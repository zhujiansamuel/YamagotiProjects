# %%
from pathlib import Path
import pandas as pd
import os, re, json, pathlib
from typing import Dict, Optional, List, Iterable, Union
from django.utils import timezone

_AIR_PAT = re.compile(r"(iPhone)\s*(Air)(?:\s*(Pro\s*Max|Pro|Plus|mini))?", re.I)

_NUM_MODEL_PAT = re.compile(r"(iPhone)\s*(\d{2})(?:\s*(Pro\s*Max|Pro|Plus|mini))?", re.I)

def _parse_capacity_gb(text: str) -> Optional[int]:
    if not text:
        return None
    t = str(text)
    m = re.search(r"(\d+(?:\.\d+)?)\s*TB", t, flags=re.I)
    if m:
        return int(round(float(m.group(1)) * 1024))
    m = re.search(r"(\d{2,4})\s*GB", t, flags=re.I)
    if m:
        return int(m.group(1))
    return None

def to_int_yen(s: object) -> Optional[int]:
    if s is None: return None
    txt = str(s).strip()
    if not re.search(r"\d", txt): return None
    # 范围 "105,000～110,000"
    parts = re.split(r"[~～\-–—]", txt)
    candidates = []
    for p in parts:
        # 排除 12-14 位纯数字（像 JAN/电话）
        if re.fullmatch(r"\d{12,14}", p.strip()):
            continue
        digits = re.sub(r"[^\d万]", "", p)
        if not digits:
            continue
        if "万" in digits:
            m = re.search(r"([\d\.]+)万", digits)
            base = float(m.group(1)) if m else 0.0
            candidates.append(int(base * 10000))
        else:
            candidates.append(int(re.sub(r"[^\d]", "", digits)))
    if not candidates:
        return None
    val = max(candidates)
    # 合理区间过滤
    if val < 1000 or val > 5_000_000:
        return None
    return val

def _norm(s: str) -> str:
    return (s or "").strip()


def _price_from_shop7(x: object) -> Optional[int]:
    """data2 -> price_new：去掉“新品/未開封/货币符号/逗号”，区间取最大"""
    if x is None:
        return None
    s = str(x)
    s = s.replace("新品", "").replace("新\u54c1", "")
    s = s.replace("未開封", "").replace("未开封", "")
    return to_int_yen(s)



def _load_iphone17_info_df_for_shop2() -> pd.DataFrame:
    """
    读取 AppleStockChecker/data/iphone17_info.csv 或 settings / env 指定的路径。
    输出列：part_number, model_name_norm, capacity_gb
    """
    path = "/Users/syu/PycharmProjects/YamagotiProjects/AppleStockChecker/data/iphone17_info.csv"
    pth = Path(path)
    if not pth.exists():
        raise FileNotFoundError(f"未找到 iphone17_info：{pth}")

    if re.search(r"\.(xlsx|xlsm|xls|ods)$", str(pth), re.I):
        df = pd.read_excel(pth)
    else:
        df = pd.read_csv(pth, encoding="utf-8-sig")

    need = {"part_number", "model_name", "capacity_gb","color"}
    missing = need - set(df.columns)
    if missing:
        raise ValueError(f"iphone17_info 缺少必要列：{missing}")

    df = df.copy()
    # df["model_name_norm"] = df["model_name"].map(_normalize_model_generic)
    df["capacity_gb"] = pd.to_numeric(df["capacity_gb"], errors="coerce").astype("Int64")
    df = df.dropna(subset=["model_name", "capacity_gb", "part_number","color"])
    return df[["part_number", "model_name", "capacity_gb","color"]]

def _normalize_model_generic(text: str) -> str:
    """
    统一型号主体：
      - iPhone17/16 + 后缀（Pro/Pro Max/Plus/mini）
      - iPhone Air（含“17 air”→ Air）
      - 允许紧凑写法：17pro / 17promax / 16Pro / 16Plus ...
    输出：'iPhone 17 Pro Max' / 'iPhone 17 Pro' / 'iPhone Air' / ...
    """
    if not text:
        return ""
    t = str(text).replace("\u3000", " ")
    t = re.sub(r"\s+", " ", t)

    # 日文别名到英文
    t = (t.replace("プロマックス", "Pro Max")
           .replace("プロ", "Pro")
           .replace("プラス", "Plus")
           .replace("ミニ", "mini")
           .replace("エアー", "Air")
           .replace("エア", "Air"))

    # ❗ 在“数字后立即跟英文”的位置补一个空格：17pro -> 17 pro
    t = re.sub(r"(\d{2})(?=[A-Za-z])", r"\1 ", t)

    # 标准化大小写/形态：pro-max / ProMax / promáx → Pro Max；pro → Pro；plus → Plus；mini → mini
    t = re.sub(r"(?i)\bpro\s*max\b", "Pro Max", t)
    t = re.sub(r"(?i)\bpro\b", "Pro", t)
    t = re.sub(r"(?i)\bplus\b", "Plus", t)
    t = re.sub(r"(?i)\bmini\b", "mini", t)

    # 若没有 iPhone 前缀但出现纯数字代号，补上
    if "iPhone" not in t and re.search(r"\b1[0-9]\b", t):
        t = re.sub(r"\b(1[0-9])\b", r"iPhone \1", t, count=1)

    # 特例：'17 air' → iPhone Air（防止被当成 iPhone 17）
    t = re.sub(r"(?i)\biPhone\s+17\s+Air\b", "iPhone Air", t)

    # 去容量/SIM/括号噪声
    t = re.sub(r"(\d+(?:\.\d+)?\s*TB|\d{2,4}\s*GB)", "", t, flags=re.I)
    t = re.sub(r"SIMフリ[ーｰ–-]?|シムフリ[ーｰ–-]?|sim\s*free", "", t, flags=re.I)
    t = re.sub(r"[（）\(\)\[\]【】].*?[（）\(\)\[\]【】]", "", t)
    t = re.sub(r"\s+", " ", t).strip()

    # 1) 数字代号机型
    m = _NUM_MODEL_PAT.search(t)
    if m:
        base = f"{m.group(1)} {m.group(2)}"
        suf  = (m.group(3) or "").strip()
        return f"{base} {suf}".strip()

    # 2) Air
    m2 = _AIR_PAT.search(t)
    if m2:
        # 当前返回主体 'iPhone Air'；若以后真有 Air Plus 等可在此扩展
        return "iPhone Air"

    return ""


# def _norm_model_for_shop7(text: str) -> str:
#     """
#     在 _normalize_model_generic 之前做一点“shop7 特有”的宽松处理：
#       - ‘promax/ProMax/pro-max’ → ‘Pro Max’
#       - ‘17 air’ → ‘iPhone Air’
#       - 没有 iPhone 前缀但有 '17' 的，补成 ‘iPhone 17 ...’
#     然后交给 _normalize_model_generic 做最终归一。
#     """
#     if not text:
#         return ""
#     t = str(text).replace("\u3000", " ")
#     t = re.sub(r"\s+", " ", t)
#
#     # 日文/英文后缀标准化
#     t = (t.replace("プロマックス", "Pro Max")
#            .replace("プロ", "Pro")
#            .replace("プラス", "Plus")
#            .replace("ミニ", "mini")
#            .replace("エアー", "Air")
#            .replace("エア", "Air"))
#
#     # promax 连写/大小写
#     t = re.sub(r"(?i)pro[-\s]?max", "Pro Max", t)
#
#     # 若没有 iPhone 前缀但出现 "17 air" / "17 pro max" / "17 pro" / "17 plus"
#     # 先把 "17 air" 显式改成 "iPhone Air"（Air 没有数字后缀）
#     if re.search(r"(?i)\b17\s+air\b", t):
#         # 去掉“17 ”，以免 _normalize_model_generic 误识别为 iPhone 17
#         t = re.sub(r"(?i)\b17\s+air\b", "iPhone Air", t)
#
#     # 若没有 iPhone 单词但有纯数字代号（例如 "17 Pro Max 256GB"）
#     if "iPhone" not in t and re.search(r"\b1[0-9]\b", t):
#         t = re.sub(r"\b(1[0-9])\b", r"iPhone \1", t, count=1)
#
#     return _normalize_model_generic(t)

# %%
import re
import time
from typing import Dict, List, Tuple, Optional

def clean_shop7(df: pd.DataFrame) -> pd.DataFrame:
    print("DEBUG: shop7:買取ホムラ ----------> 进入清洗器 时间:", time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    _SHORT_MODEL_REPLACEMENTS = [
    (re.compile(r'(?i)\b17\s*pro\s*max\b'), "iPhone 17 Pro Max"),
    (re.compile(r'(?i)\b17promax\b'), "iPhone 17 Pro Max"),
    (re.compile(r'(?i)\b17\s*pro\b'), "iPhone 17 Pro"),
    (re.compile(r'(?i)\b17pro\b'), "iPhone 17 Pro"),
    (re.compile(r'(?i)\b17\s*air\b'), "iPhone 17 Air"),
    (re.compile(r'(?i)\b17air\b'), "iPhone 17 Air"),
    (re.compile(r'(?i)\bi\s*phone\s*17\b'), "iPhone 17"),
    (re.compile(r'(?i)\b17\b'), "iPhone 17"),  # 小心：放最后做兜底
]
    def _norm_model_for_shop7(s: Optional[str]) -> str:
        """
        针对 shop7 的 model 字段做宽松归一化：
          - 跳过纯数字的行（返回空字符串）
          - 将 '17pro', '17promax', '17 pro max' 等短写扩展为 'iPhone 17 Pro Max'
          - 最后调用 _normalize_model_generic 生成最终的归一字符串（与 info 表匹配）
        返回 '' 表示无法识别（将被跳过）
        """
        if s is None:
            return ""
        txt = str(s).strip()
        if not txt:
            return ""

        # 跳过行号/序号（仅数字或少量标点）
        if re.fullmatch(r'[\d\-\.\s]+', txt):
            # 代表这是序号/编号行，例如 "1", "2" 等
            return ""

        # 统一全角空格 & 多余空白
        txt = re.sub(r'[\u3000\s]+', ' ', txt).strip()

        # 先把常用短写替换成标准形式
        expanded = txt
        for patt, repl in _SHORT_MODEL_REPLACEMENTS:
            expanded = patt.sub(repl, expanded)

        # 可能存在像 "17pro 256GB" 或 "17promax 256GB" 这样的，
        # 上面的替换会把它变成 "iPhone 17 Pro 256GB" 之类，交给 normalize 处理。
        try:
            norm = _normalize_model_generic(expanded)
        except Exception:
            # 若 _normalize_model_generic 出错，退化为简单返回 expanded（再由上级判定是否匹配）
            norm = expanded

        # 如果 normalize 后为空或仅数字，认为无法识别
        if not norm or re.fullmatch(r'[\d\-\.\s]+', str(norm).strip()):
            return ""
        print(norm)
        return norm

    info_df = _load_iphone17_info_df_for_shop2()  # part_number, model_name_norm, capacity_gb, color

    # 必要列检查
    need_cols = ["data", "data2", "time-scraped"]
    for c in need_cols:
        if c not in df.columns:
            raise ValueError(f"shop7 清洗器缺少必要列：{c}")

    # 先把 time-scraped 为空的行排除，避免时间解析报错
    df = df.copy().reset_index(drop=True)
    mask_time_ok = df["time-scraped"].astype(str).str.strip().ne("") & df["time-scraped"].notna()
    df = df[mask_time_ok].reset_index(drop=True)
    if df.empty:
        print("DEBUG: 输入 df 为空或所有行 time-scraped 缺失，返回空 DataFrame")
        return pd.DataFrame(columns=["part_number","shop_name","price_new","recorded_at"])

    # data -> 机型&容量
    model_norm_series = df["data2"].map(_norm_model_for_shop7)
    print(model_norm_series)
    cap_gb_series     = df["data2"].map(_parse_capacity_gb)

    # 价格/时间（注意 data2 里是价格，我们仅在行有 price 时才处理该行）
    price_series  = df["data3"].map(_price_from_shop7)
    recorded_at   = df["time-scraped"]

    # ------------- 构建 (model_norm, cap) -> { color_norm: part_number } -------------
    info2 = info_df.copy()
    if "color" not in info2.columns:
        raise ValueError("info_df 缺少 'color' 列，无法进行颜色映射")
    info2["model_name_norm"] = info2["model_name"].map(_normalize_model_generic)
    info2["capacity_gb"] = pd.to_numeric(info2["capacity_gb"], errors="coerce").astype("Int64")
    info2["color_norm"] = info2["color"].map(lambda x: _norm(str(x)))

    pn_map: Dict[Tuple[str, int], Dict[str, str]] = {}
    for _, r in info2.iterrows():
        m = r["model_name_norm"]
        cap = r["capacity_gb"]
        col = r["color_norm"]
        pn = str(r["part_number"])
        if pd.isna(cap) or not m or not col:
            continue
        key = (m, int(cap))
        pn_map.setdefault(key, {})
        pn_map[key][col] = pn

    print(f"DEBUG: 建立了 pn_map，包含 {len(pn_map)} 个 (model,cap) 条目")

    # ----------------- 颜色减价解析函数（shop7 专用） -----------------
    DELTA_RE = re.compile(
        r"(?P<labels>[^\d¥￥円\+\-−－]+?)\s*(?P<sign>[+\-−－])\s*(?P<amount>[0-9０-９,，]+)",
        re.UNICODE
    )

    FW_TO_ASC = str.maketrans({
        "０":"0","１":"1","２":"2","３":"3","４":"4","５":"5","６":"6","７":"7","８":"8","９":"9",
        "，":",","．":".","－":"-","＋":"+","　":" "
    })

    def _to_int_amount(s: str) -> Optional[int]:
        if s is None:
            return None
        t = str(s).translate(FW_TO_ASC)
        m = re.search(r"([0-9][0-9,]*)", t)
        if not m:
            return None
        try:
            return int(m.group(1).replace(",", ""))
        except Exception:
            return None

    def _parse_color_deltas_shop7(text: str) -> Dict[str, int]:
        res: Dict[str, int] = {}
        if not text or not str(text).strip():
            return res
        s = str(text).strip()
        parts = []
        # 尝试先用 DELTA_RE 匹配整段里的所有有金额的片段；若没则按分隔符拆
        found = False
        for m in DELTA_RE.finditer(s):
            found = True
            labels_part = m.group("labels") or ""
            sign = m.group("sign") or "+"
            amt_txt = m.group("amount")
            amt = _to_int_amount(amt_txt)
            if amt is None:
                continue
            delta = -int(amt) if sign in ("-", "−", "－") else int(amt)
            # labels_part 可能包含多个颜色，用常见分隔符拆
            for tok in re.split(r"[／/、，,・\s]+", labels_part):
                tok = tok.strip()
                if not tok:
                    continue
                key = _norm(tok)
                res[key] = delta
        if not found:
            # 退化处理：没有显式金额匹配的情况下，尝试找类似 "シルバー/ディープブルー-3000" 形式
            # 以最后出现的 +/- 数字为金额，前面子串作为标签
            # 例如 "シルバー/ディープブルー-3000"
            m2 = re.search(r"(?P<labels>.+?)[\s]*([+\-−－])\s*(?P<amount>[0-9０-９,，]+)", s)
            if m2:
                labels_part = m2.group("labels") or ""
                sign = m2.group(2) or "+"
                amt_txt = m2.group("amount")
                amt = _to_int_amount(amt_txt)
                if amt is not None:
                    delta = -int(amt) if sign in ("-", "−", "－") else int(amt)
                    for tok in re.split(r"[／/、，,・\s]+", labels_part):
                        tok = tok.strip()
                        if tok:
                            res[_norm(tok)] = delta
        # Debug print for parsed deltas
        if res:
            print(f"DEBUG: 解析到 color deltas from '{text}': {res}")
        else:
            print(f"DEBUG: 未解析到 color deltas from '{text}'")
        return res

    # ----------------- 主循环：遍历含价格的行 -----------------
    rows: List[dict] = []
    n = len(df)
    for i in range(n):
        base_price = price_series.iat[i]
        if base_price is None:
            # 不是机种行（或者是下行的颜色行），跳过
            continue

        model_text_raw = df["data"].iat[i] if df["data"].iat[i] is not None else ""
        m = model_norm_series.iat[i]
        c = cap_gb_series.iat[i]
        t = recorded_at.iat[i]
        print(f"DEBUG: 处理行 i={i}, model_raw='{model_text_raw}', model_norm='{m}', cap='{c}', base_price={base_price}")

        if not m or pd.isna(c):
            print(f"DEBUG: 跳过 i={i} 因为 model/cap 缺失")
            continue
        c = int(c)
        key = (m, c)
        color_to_pn = pn_map.get(key)
        print(f"DEBUG: 对应的 color->pn 映射: {color_to_pn}")
        if not color_to_pn:
            print(f"DEBUG: info 表中未找到该机型容量 key={key}，跳过 i={i}")
            continue

        # 检查下一行是否为颜色减价行：下一行 data 非空 且 data2 为空
        deltas: Dict[str, int] = {}
        j = i + 1
        if j < n:
            nxt_data = df["data2"].iat[j] if df["data2"].iat[j] is not None else ""
            nxt_data2 = df["data3"].iat[j] if "data3" in df.columns and df["data2"].iat[j] is not None else ""
            if str(nxt_data).strip() and (str(nxt_data2).strip() == "" or pd.isna(nxt_data2)):
                print(f"DEBUG: 发现潜在颜色行 at i+1={j}: '{nxt_data}'")
                deltas = _parse_color_deltas_shop7(nxt_data)
            else:
                print(f"DEBUG: 下一行 i+1={j} 不是颜色行 (data='{nxt_data}' data2='{nxt_data2}')")

        # 生成每个颜色的 price_new
        for col_norm, pn in color_to_pn.items():
            delta = 0
            if deltas:
                if col_norm in deltas:
                    delta = deltas[col_norm]
                    print(f"DEBUG: 直接匹配 col_norm='{col_norm}' 得到 delta={delta} for pn={pn}")
                else:
                    # 进一步尝试在 info2 中查原始 color 文本匹配 deltas 的 key
                    matches = info2[
                        (info2["model_name_norm"] == m) &
                        (info2["capacity_gb"].astype("Int64") == c) &
                        (info2["part_number"].astype(str) == str(pn))
                    ]
                    raw_color = matches["color"].iat[0] if not matches.empty else ""
                    matched = False
                    for lbl_norm, dval in deltas.items():
                        # 尝试在 raw_color 的归一化字符串中查找 lbl_norm
                        if lbl_norm and lbl_norm in _norm(raw_color):
                            delta = dval
                            matched = True
                            print(f"DEBUG: 通过 raw_color='{raw_color}' 的归一化匹配 lbl='{lbl_norm}' -> delta={delta} for pn={pn}")
                            break
                        # 也尝试原文子串匹配
                        if lbl_norm and lbl_norm in raw_color:
                            delta = dval
                            matched = True
                            print(f"DEBUG: 通过 raw_color 原文匹配 lbl='{lbl_norm}' -> delta={delta} for pn={pn}")
                            break
                    if not matched and deltas:
                        print(f"DEBUG: 未匹配到颜色调整 for pn={pn} (raw_color='{raw_color}'), 使用 delta=0")

            price_final = int(base_price + delta)
            print(f"DEBUG: 输出 -> pn={pn}, base={base_price}, delta={delta}, final={price_final}")
            rows.append({
                "part_number": str(pn),
                "shop_name": "買取ホムラ",
                "price_new": price_final,
                "recorded_at": t,
            })

    out = pd.DataFrame(rows, columns=["part_number","shop_name","price_new","recorded_at"])
    if not out.empty:
        out = out.dropna(subset=["part_number","price_new"]).reset_index(drop=True)
        out["part_number"] = out["part_number"].astype(str)
        out["price_new"] = pd.to_numeric(out["price_new"], errors="coerce").astype("Int64")
    print("DEBUG: 完成 clean_shop7, 产出行数:", len(out))
    return out

# %%
df_7 = pd.read_csv("/Users/syu/PycharmProjects/YamagotiProjects/docs-google-com-2025-10-27 (1).csv")
df_7
# Out:
#     web-scraper-order  data        data2     data3 data4         time-scraped
# 0        1761548267-1     1     【未開封】商品名       NaN   NaN  2025-10-27 15:57:47
# 1        1761548267-2     2  17pro 256GB  ¥176,000   NaN  2025-10-27 15:57:47
# 2        1761548267-3     3          NaN       NaN   NaN  2025-10-27 15:57:47
# 3        1761548267-4     4  17pro 512GB  ¥212,000   NaN  2025-10-27 15:57:47
# 4        1761548267-5     5          NaN       NaN   NaN  2025-10-27 15:57:47
# ..                ...   ...          ...       ...   ...                  ...
# 127    1761548267-128   128          NaN       NaN   NaN  2025-10-27 15:57:47
# 128    1761548267-129   149     SE3 64GB   ¥45,000   NaN  2025-10-27 15:57:47
# 129    1761548267-130   150     △-13,000       NaN   NaN  2025-10-27 15:57:47
# 130    1761548267-131   151    SE3 128GB   ¥49,000   NaN  2025-10-27 15:57:47
# 131    1761548267-132   152      △-7,000       NaN   NaN  2025-10-27 15:57:47
#
# [132 rows x 6 columns]

# %%
res = clean_shop7(df_7)
res
# Out:
# DEBUG: shop7:買取ホムラ ----------> 进入清洗器 时间: 2025-10-27 16:48:30
# iPhone 17 Pro
# iPhone 17 Pro
# iPhone 17 Pro
# iPhone 17 Pro Max
# iPhone 17 Pro Max
# iPhone 17 Pro Max
# iPhone 17 Pro Max
# iPhone Air
# iPhone Air
# iPhone Air
# iPhone 17
# iPhone 17
# iPhone 16 Pro
# iPhone 16 Pro
# iPhone 16 Pro
# iPhone 16 Pro
# iPhone 16 Pro Max
# iPhone 16 Pro Max
# iPhone 16 Pro Max
# iPhone 16
# iPhone 16
# iPhone 16
# iPhone 16 Plus
# iPhone 16 Plus
# iPhone 16 Plus
# iPhone 16
# iPhone 16
# iPhone 16
# iPhone 15 Pro
# iPhone 15 Pro
# iPhone 15 Pro
# iPhone 15 Pro
# iPhone 15 Pro Max
# iPhone 15 Pro Max
# iPhone 15 Pro Max
# iPhone 15
# iPhone 15
# iPhone 15
# iPhone 15 Plus
# iPhone 15 Plus
# iPhone 15 Plus
# iPhone 14 Pro
# iPhone 14 Pro
# iPhone 14 Pro
# iPhone 14 Pro
# iPhone 14 Pro Max
# iPhone 14 Pro Max
# iPhone 14 Pro Max
# iPhone 14 Pro Max
# iPhone 14
# iPhone 14
# iPhone 14
# iPhone 14 Plus
# iPhone 14 Plus
# iPhone 14 Plus
# iPhone 13
# 0
# 1      iPhone 17 Pro
# 2
# 3      iPhone 17 Pro
# 4
#            ...
# 127
# 128
# 129        iPhone 13
# 130
# 131
# Name: data2, Length: 132, dtype: object
# DEBUG: 建立了 pn_map，包含 12 个 (model,cap) 条目
# DEBUG: 处理行 i=0, model_raw='1', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=0 因为 model/cap 缺失
# DEBUG: 处理行 i=1, model_raw='2', model_norm='iPhone 17 Pro', cap='256.0', base_price=176000.0
# DEBUG: 对应的 color->pn 映射: {'シルバー': 'MG854J/A', 'コズミックオレンジ': 'MG864J/A', 'ディープブルー': 'MG874J/A'}
# DEBUG: 发现潜在颜色行 at i+1=2: 'nan'
# DEBUG: 未解析到 color deltas from 'nan'
# DEBUG: 输出 -> pn=MG854J/A, base=176000.0, delta=0, final=176000
# DEBUG: 输出 -> pn=MG864J/A, base=176000.0, delta=0, final=176000
# DEBUG: 输出 -> pn=MG874J/A, base=176000.0, delta=0, final=176000
# DEBUG: 处理行 i=2, model_raw='3', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=2 因为 model/cap 缺失
# DEBUG: 处理行 i=3, model_raw='4', model_norm='iPhone 17 Pro', cap='512.0', base_price=212000.0
# DEBUG: 对应的 color->pn 映射: {'シルバー': 'MG894J/A', 'コズミックオレンジ': 'MG8A4J/A', 'ディープブルー': 'MG8C4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=4: 'nan'
# DEBUG: 未解析到 color deltas from 'nan'
# DEBUG: 输出 -> pn=MG894J/A, base=212000.0, delta=0, final=212000
# DEBUG: 输出 -> pn=MG8A4J/A, base=212000.0, delta=0, final=212000
# DEBUG: 输出 -> pn=MG8C4J/A, base=212000.0, delta=0, final=212000
# DEBUG: 处理行 i=4, model_raw='5', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=4 因为 model/cap 缺失
# DEBUG: 处理行 i=5, model_raw='6', model_norm='iPhone 17 Pro', cap='1024.0', base_price=245000.0
# DEBUG: 对应的 color->pn 映射: {'シルバー': 'MG8D4J/A', 'コズミックオレンジ': 'MG8E4J/A', 'ディープブルー': 'MG8F4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=6: 'nan'
# DEBUG: 未解析到 color deltas from 'nan'
# DEBUG: 输出 -> pn=MG8D4J/A, base=245000.0, delta=0, final=245000
# DEBUG: 输出 -> pn=MG8E4J/A, base=245000.0, delta=0, final=245000
# DEBUG: 输出 -> pn=MG8F4J/A, base=245000.0, delta=0, final=245000
# DEBUG: 处理行 i=6, model_raw='7', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=6 因为 model/cap 缺失
# DEBUG: 处理行 i=7, model_raw='8', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=7 因为 model/cap 缺失
# DEBUG: 处理行 i=8, model_raw='9', model_norm='iPhone 17 Pro Max', cap='256.0', base_price=198000.0
# DEBUG: 对应的 color->pn 映射: {'シルバー': 'MFY84J/A', 'コズミックオレンジ': 'MFY94J/A', 'ディープブルー': 'MFYA4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=9: 'nan'
# DEBUG: 未解析到 color deltas from 'nan'
# DEBUG: 输出 -> pn=MFY84J/A, base=198000.0, delta=0, final=198000
# DEBUG: 输出 -> pn=MFY94J/A, base=198000.0, delta=0, final=198000
# DEBUG: 输出 -> pn=MFYA4J/A, base=198000.0, delta=0, final=198000
# DEBUG: 处理行 i=9, model_raw='10', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=9 因为 model/cap 缺失
# DEBUG: 处理行 i=10, model_raw='11', model_norm='iPhone 17 Pro Max', cap='512.0', base_price=230500.0
# DEBUG: 对应的 color->pn 映射: {'シルバー': 'MFYC4J/A', 'コズミックオレンジ': 'MFYD4J/A', 'ディープブルー': 'MFYE4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=11: 'シルバー-1500,ブルー-1500'
# DEBUG: 解析到 color deltas from 'シルバー-1500,ブルー-1500': {'シルバー': -1500, 'ブルー': -1500}
# DEBUG: 直接匹配 col_norm='シルバー' 得到 delta=-1500 for pn=MFYC4J/A
# DEBUG: 输出 -> pn=MFYC4J/A, base=230500.0, delta=-1500, final=229000
# DEBUG: 未匹配到颜色调整 for pn=MFYD4J/A (raw_color='コズミックオレンジ'), 使用 delta=0
# DEBUG: 输出 -> pn=MFYD4J/A, base=230500.0, delta=0, final=230500
# DEBUG: 通过 raw_color='ディープブルー' 的归一化匹配 lbl='ブルー' -> delta=-1500 for pn=MFYE4J/A
# DEBUG: 输出 -> pn=MFYE4J/A, base=230500.0, delta=-1500, final=229000
# DEBUG: 处理行 i=11, model_raw='12', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=11 因为 model/cap 缺失
# DEBUG: 处理行 i=12, model_raw='13', model_norm='iPhone 17 Pro Max', cap='1024.0', base_price=263000.0
# DEBUG: 对应的 color->pn 映射: {'シルバー': 'MFYF4J/A', 'コズミックオレンジ': 'MFYG4J/A', 'ディープブルー': 'MFYH4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=13: 'シルバー-3000,ブルー-3000'
# DEBUG: 解析到 color deltas from 'シルバー-3000,ブルー-3000': {'シルバー': -3000, 'ブルー': -3000}
# DEBUG: 直接匹配 col_norm='シルバー' 得到 delta=-3000 for pn=MFYF4J/A
# DEBUG: 输出 -> pn=MFYF4J/A, base=263000.0, delta=-3000, final=260000
# DEBUG: 未匹配到颜色调整 for pn=MFYG4J/A (raw_color='コズミックオレンジ'), 使用 delta=0
# DEBUG: 输出 -> pn=MFYG4J/A, base=263000.0, delta=0, final=263000
# DEBUG: 通过 raw_color='ディープブルー' 的归一化匹配 lbl='ブルー' -> delta=-3000 for pn=MFYH4J/A
# DEBUG: 输出 -> pn=MFYH4J/A, base=263000.0, delta=-3000, final=260000
# DEBUG: 处理行 i=13, model_raw='14', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=13 因为 model/cap 缺失
# DEBUG: 处理行 i=14, model_raw='15', model_norm='iPhone 17 Pro Max', cap='2048.0', base_price=314000.0
# DEBUG: 对应的 color->pn 映射: {'シルバー': 'MFYJ4J/A', 'コズミックオレンジ': 'MFYK4J/A', 'ディープブルー': 'MFYL4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=15: 'シルバー-3000,ブルー-3000'
# DEBUG: 解析到 color deltas from 'シルバー-3000,ブルー-3000': {'シルバー': -3000, 'ブルー': -3000}
# DEBUG: 直接匹配 col_norm='シルバー' 得到 delta=-3000 for pn=MFYJ4J/A
# DEBUG: 输出 -> pn=MFYJ4J/A, base=314000.0, delta=-3000, final=311000
# DEBUG: 未匹配到颜色调整 for pn=MFYK4J/A (raw_color='コズミックオレンジ'), 使用 delta=0
# DEBUG: 输出 -> pn=MFYK4J/A, base=314000.0, delta=0, final=314000
# DEBUG: 通过 raw_color='ディープブルー' 的归一化匹配 lbl='ブルー' -> delta=-3000 for pn=MFYL4J/A
# DEBUG: 输出 -> pn=MFYL4J/A, base=314000.0, delta=-3000, final=311000
# DEBUG: 处理行 i=15, model_raw='16', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=15 因为 model/cap 缺失
# DEBUG: 处理行 i=16, model_raw='17', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=16 因为 model/cap 缺失
# DEBUG: 处理行 i=17, model_raw='18', model_norm='iPhone Air', cap='256.0', base_price=127000.0
# DEBUG: 对应的 color->pn 映射: {'スペースブラック': 'MG274J/A', 'クラウドホワイト': 'MG284J/A', 'ライトゴールド': 'MG294J/A', 'スカイブルー': 'MG2A4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=18: 'ブルー-2000'
# DEBUG: 解析到 color deltas from 'ブルー-2000': {'ブルー': -2000}
# DEBUG: 未匹配到颜色调整 for pn=MG274J/A (raw_color='スペースブラック'), 使用 delta=0
# DEBUG: 输出 -> pn=MG274J/A, base=127000.0, delta=0, final=127000
# DEBUG: 未匹配到颜色调整 for pn=MG284J/A (raw_color='クラウドホワイト'), 使用 delta=0
# DEBUG: 输出 -> pn=MG284J/A, base=127000.0, delta=0, final=127000
# DEBUG: 未匹配到颜色调整 for pn=MG294J/A (raw_color='ライトゴールド'), 使用 delta=0
# DEBUG: 输出 -> pn=MG294J/A, base=127000.0, delta=0, final=127000
# DEBUG: 通过 raw_color='スカイブルー' 的归一化匹配 lbl='ブルー' -> delta=-2000 for pn=MG2A4J/A
# DEBUG: 输出 -> pn=MG2A4J/A, base=127000.0, delta=-2000, final=125000
# DEBUG: 处理行 i=18, model_raw='19', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=18 因为 model/cap 缺失
# DEBUG: 处理行 i=19, model_raw='20', model_norm='iPhone Air', cap='512.0', base_price=140000.0
# DEBUG: 对应的 color->pn 映射: {'スペースブラック': 'MG2C4J/A', 'クラウドホワイト': 'MG2D4J/A', 'ライトゴールド': 'MG2E4J/A', 'スカイブルー': 'MG2F4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=20: 'ブラック-4000,ブルー-4000'
# DEBUG: 解析到 color deltas from 'ブラック-4000,ブルー-4000': {'ブラック': -4000, 'ブルー': -4000}
# DEBUG: 通过 raw_color='スペースブラック' 的归一化匹配 lbl='ブラック' -> delta=-4000 for pn=MG2C4J/A
# DEBUG: 输出 -> pn=MG2C4J/A, base=140000.0, delta=-4000, final=136000
# DEBUG: 未匹配到颜色调整 for pn=MG2D4J/A (raw_color='クラウドホワイト'), 使用 delta=0
# DEBUG: 输出 -> pn=MG2D4J/A, base=140000.0, delta=0, final=140000
# DEBUG: 未匹配到颜色调整 for pn=MG2E4J/A (raw_color='ライトゴールド'), 使用 delta=0
# DEBUG: 输出 -> pn=MG2E4J/A, base=140000.0, delta=0, final=140000
# DEBUG: 通过 raw_color='スカイブルー' 的归一化匹配 lbl='ブルー' -> delta=-4000 for pn=MG2F4J/A
# DEBUG: 输出 -> pn=MG2F4J/A, base=140000.0, delta=-4000, final=136000
# DEBUG: 处理行 i=20, model_raw='21', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=20 因为 model/cap 缺失
# DEBUG: 处理行 i=21, model_raw='22', model_norm='iPhone Air', cap='1024.0', base_price=154000.0
# DEBUG: 对应的 color->pn 映射: {'スペースブラック': 'MG2G4J/A', 'クラウドホワイト': 'MG2H4J/A', 'ライトゴールド': 'MG2J4J/A', 'スカイブルー': 'MG2K4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=22: 'ブラック-4000,ブルー-4000'
# DEBUG: 解析到 color deltas from 'ブラック-4000,ブルー-4000': {'ブラック': -4000, 'ブルー': -4000}
# DEBUG: 通过 raw_color='スペースブラック' 的归一化匹配 lbl='ブラック' -> delta=-4000 for pn=MG2G4J/A
# DEBUG: 输出 -> pn=MG2G4J/A, base=154000.0, delta=-4000, final=150000
# DEBUG: 未匹配到颜色调整 for pn=MG2H4J/A (raw_color='クラウドホワイト'), 使用 delta=0
# DEBUG: 输出 -> pn=MG2H4J/A, base=154000.0, delta=0, final=154000
# DEBUG: 未匹配到颜色调整 for pn=MG2J4J/A (raw_color='ライトゴールド'), 使用 delta=0
# DEBUG: 输出 -> pn=MG2J4J/A, base=154000.0, delta=0, final=154000
# DEBUG: 通过 raw_color='スカイブルー' 的归一化匹配 lbl='ブルー' -> delta=-4000 for pn=MG2K4J/A
# DEBUG: 输出 -> pn=MG2K4J/A, base=154000.0, delta=-4000, final=150000
# DEBUG: 处理行 i=22, model_raw='23', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=22 因为 model/cap 缺失
# DEBUG: 处理行 i=23, model_raw='24', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=23 因为 model/cap 缺失
# DEBUG: 处理行 i=24, model_raw='25', model_norm='iPhone 17', cap='256.0', base_price=128500.0
# DEBUG: 对应的 color->pn 映射: {'ブラック': 'MG674J/A', 'ホワイト': 'MG684J/A', 'ミストブルー': 'MG694J/A', 'ラベンダー': 'MG6A4J/A', 'セージ': 'MG6C4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=25: 'nan'
# DEBUG: 未解析到 color deltas from 'nan'
# DEBUG: 输出 -> pn=MG674J/A, base=128500.0, delta=0, final=128500
# DEBUG: 输出 -> pn=MG684J/A, base=128500.0, delta=0, final=128500
# DEBUG: 输出 -> pn=MG694J/A, base=128500.0, delta=0, final=128500
# DEBUG: 输出 -> pn=MG6A4J/A, base=128500.0, delta=0, final=128500
# DEBUG: 输出 -> pn=MG6C4J/A, base=128500.0, delta=0, final=128500
# DEBUG: 处理行 i=25, model_raw='26', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=25 因为 model/cap 缺失
# DEBUG: 处理行 i=26, model_raw='27', model_norm='iPhone 17', cap='512.0', base_price=158000.0
# DEBUG: 对应的 color->pn 映射: {'ブラック': 'MG6D4J/A', 'ホワイト': 'MG6E4J/A', 'ミストブルー': 'MG6F4J/A', 'ラベンダー': 'MG6G4J/A', 'セージ': 'MG6H4J/A'}
# DEBUG: 发现潜在颜色行 at i+1=27: 'nan'
# DEBUG: 未解析到 color deltas from 'nan'
# DEBUG: 输出 -> pn=MG6D4J/A, base=158000.0, delta=0, final=158000
# DEBUG: 输出 -> pn=MG6E4J/A, base=158000.0, delta=0, final=158000
# DEBUG: 输出 -> pn=MG6F4J/A, base=158000.0, delta=0, final=158000
# DEBUG: 输出 -> pn=MG6G4J/A, base=158000.0, delta=0, final=158000
# DEBUG: 输出 -> pn=MG6H4J/A, base=158000.0, delta=0, final=158000
# DEBUG: 处理行 i=27, model_raw='28', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=27 因为 model/cap 缺失
# DEBUG: 处理行 i=28, model_raw='29', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=28 因为 model/cap 缺失
# DEBUG: 处理行 i=29, model_raw='30', model_norm='iPhone 16 Pro', cap='128.0', base_price=153000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Pro', 128)，跳过 i=29
# DEBUG: 处理行 i=30, model_raw='31', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=30 因为 model/cap 缺失
# DEBUG: 处理行 i=31, model_raw='32', model_norm='iPhone 16 Pro', cap='256.0', base_price=173500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Pro', 256)，跳过 i=31
# DEBUG: 处理行 i=32, model_raw='33', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=32 因为 model/cap 缺失
# DEBUG: 处理行 i=33, model_raw='34', model_norm='iPhone 16 Pro', cap='512.0', base_price=200500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Pro', 512)，跳过 i=33
# DEBUG: 处理行 i=34, model_raw='35', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=34 因为 model/cap 缺失
# DEBUG: 处理行 i=35, model_raw='36', model_norm='iPhone 16 Pro', cap='1024.0', base_price=218500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Pro', 1024)，跳过 i=35
# DEBUG: 处理行 i=36, model_raw='37', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=36 因为 model/cap 缺失
# DEBUG: 处理行 i=37, model_raw='38', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=37 因为 model/cap 缺失
# DEBUG: 处理行 i=38, model_raw='39', model_norm='iPhone 16 Pro Max', cap='256.0', base_price=182500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Pro Max', 256)，跳过 i=38
# DEBUG: 处理行 i=39, model_raw='40', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=39 因为 model/cap 缺失
# DEBUG: 处理行 i=40, model_raw='41', model_norm='iPhone 16 Pro Max', cap='512.0', base_price=210500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Pro Max', 512)，跳过 i=40
# DEBUG: 处理行 i=41, model_raw='42', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=41 因为 model/cap 缺失
# DEBUG: 处理行 i=42, model_raw='43', model_norm='iPhone 16 Pro Max', cap='1024.0', base_price=241500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Pro Max', 1024)，跳过 i=42
# DEBUG: 处理行 i=43, model_raw='44', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=43 因为 model/cap 缺失
# DEBUG: 处理行 i=44, model_raw='45', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=44 因为 model/cap 缺失
# DEBUG: 处理行 i=45, model_raw='46', model_norm='iPhone 16', cap='128.0', base_price=96000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16', 128)，跳过 i=45
# DEBUG: 处理行 i=46, model_raw='47', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=46 因为 model/cap 缺失
# DEBUG: 处理行 i=47, model_raw='48', model_norm='iPhone 16', cap='256.0', base_price=111500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16', 256)，跳过 i=47
# DEBUG: 处理行 i=48, model_raw='49', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=48 因为 model/cap 缺失
# DEBUG: 处理行 i=49, model_raw='50', model_norm='iPhone 16', cap='512.0', base_price=119500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16', 512)，跳过 i=49
# DEBUG: 处理行 i=50, model_raw='51', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=50 因为 model/cap 缺失
# DEBUG: 处理行 i=51, model_raw='52', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=51 因为 model/cap 缺失
# DEBUG: 处理行 i=52, model_raw='53', model_norm='iPhone 16 Plus', cap='128.0', base_price=106000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Plus', 128)，跳过 i=52
# DEBUG: 处理行 i=53, model_raw='54', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=53 因为 model/cap 缺失
# DEBUG: 处理行 i=54, model_raw='55', model_norm='iPhone 16 Plus', cap='256.0', base_price=118500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Plus', 256)，跳过 i=54
# DEBUG: 处理行 i=55, model_raw='56', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=55 因为 model/cap 缺失
# DEBUG: 处理行 i=56, model_raw='57', model_norm='iPhone 16 Plus', cap='512.0', base_price=127000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16 Plus', 512)，跳过 i=56
# DEBUG: 处理行 i=57, model_raw='58', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=57 因为 model/cap 缺失
# DEBUG: 处理行 i=58, model_raw='59', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=58 因为 model/cap 缺失
# DEBUG: 处理行 i=59, model_raw='60', model_norm='iPhone 16', cap='128.0', base_price=nan
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16', 128)，跳过 i=59
# DEBUG: 处理行 i=60, model_raw='61', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=60 因为 model/cap 缺失
# DEBUG: 处理行 i=61, model_raw='62', model_norm='iPhone 16', cap='256.0', base_price=nan
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16', 256)，跳过 i=61
# DEBUG: 处理行 i=62, model_raw='63', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=62 因为 model/cap 缺失
# DEBUG: 处理行 i=63, model_raw='64', model_norm='iPhone 16', cap='512.0', base_price=nan
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 16', 512)，跳过 i=63
# DEBUG: 处理行 i=64, model_raw='65', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=64 因为 model/cap 缺失
# DEBUG: 处理行 i=65, model_raw='66', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=65 因为 model/cap 缺失
# DEBUG: 处理行 i=66, model_raw='67', model_norm='iPhone 15 Pro', cap='128.0', base_price=131000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Pro', 128)，跳过 i=66
# DEBUG: 处理行 i=67, model_raw='68', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=67 因为 model/cap 缺失
# DEBUG: 处理行 i=68, model_raw='69', model_norm='iPhone 15 Pro', cap='256.0', base_price=141000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Pro', 256)，跳过 i=68
# DEBUG: 处理行 i=69, model_raw='70', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=69 因为 model/cap 缺失
# DEBUG: 处理行 i=70, model_raw='71', model_norm='iPhone 15 Pro', cap='512.0', base_price=151000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Pro', 512)，跳过 i=70
# DEBUG: 处理行 i=71, model_raw='72', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=71 因为 model/cap 缺失
# DEBUG: 处理行 i=72, model_raw='73', model_norm='iPhone 15 Pro', cap='1024.0', base_price=158000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Pro', 1024)，跳过 i=72
# DEBUG: 处理行 i=73, model_raw='74', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=73 因为 model/cap 缺失
# DEBUG: 处理行 i=74, model_raw='75', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=74 因为 model/cap 缺失
# DEBUG: 处理行 i=75, model_raw='76', model_norm='iPhone 15 Pro Max', cap='256.0', base_price=155000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Pro Max', 256)，跳过 i=75
# DEBUG: 处理行 i=76, model_raw='77', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=76 因为 model/cap 缺失
# DEBUG: 处理行 i=77, model_raw='78', model_norm='iPhone 15 Pro Max', cap='512.0', base_price=167000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Pro Max', 512)，跳过 i=77
# DEBUG: 处理行 i=78, model_raw='79', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=78 因为 model/cap 缺失
# DEBUG: 处理行 i=79, model_raw='80', model_norm='iPhone 15 Pro Max', cap='1024.0', base_price=174000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Pro Max', 1024)，跳过 i=79
# DEBUG: 处理行 i=80, model_raw='81', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=80 因为 model/cap 缺失
# DEBUG: 处理行 i=81, model_raw='82', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=81 因为 model/cap 缺失
# DEBUG: 处理行 i=82, model_raw='83', model_norm='iPhone 15', cap='128.0', base_price=82000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15', 128)，跳过 i=82
# DEBUG: 处理行 i=83, model_raw='84', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=83 因为 model/cap 缺失
# DEBUG: 处理行 i=84, model_raw='85', model_norm='iPhone 15', cap='256.0', base_price=92000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15', 256)，跳过 i=84
# DEBUG: 处理行 i=85, model_raw='86', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=85 因为 model/cap 缺失
# DEBUG: 处理行 i=86, model_raw='87', model_norm='iPhone 15', cap='512.0', base_price=100000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15', 512)，跳过 i=86
# DEBUG: 处理行 i=87, model_raw='88', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=87 因为 model/cap 缺失
# DEBUG: 处理行 i=88, model_raw='89', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=88 因为 model/cap 缺失
# DEBUG: 处理行 i=89, model_raw='90', model_norm='iPhone 15 Plus', cap='128.0', base_price=97000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Plus', 128)，跳过 i=89
# DEBUG: 处理行 i=90, model_raw='91', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=90 因为 model/cap 缺失
# DEBUG: 处理行 i=91, model_raw='92', model_norm='iPhone 15 Plus', cap='256.0', base_price=107000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Plus', 256)，跳过 i=91
# DEBUG: 处理行 i=92, model_raw='93', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=92 因为 model/cap 缺失
# DEBUG: 处理行 i=93, model_raw='94', model_norm='iPhone 15 Plus', cap='512.0', base_price=113000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 15 Plus', 512)，跳过 i=93
# DEBUG: 处理行 i=94, model_raw='95', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=94 因为 model/cap 缺失
# DEBUG: 处理行 i=95, model_raw='96', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=95 因为 model/cap 缺失
# DEBUG: 处理行 i=96, model_raw='97', model_norm='iPhone 14 Pro', cap='128.0', base_price=100000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Pro', 128)，跳过 i=96
# DEBUG: 处理行 i=97, model_raw='98', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=97 因为 model/cap 缺失
# DEBUG: 处理行 i=98, model_raw='99', model_norm='iPhone 14 Pro', cap='256.0', base_price=105000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Pro', 256)，跳过 i=98
# DEBUG: 处理行 i=99, model_raw='100', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=99 因为 model/cap 缺失
# DEBUG: 处理行 i=100, model_raw='101', model_norm='iPhone 14 Pro', cap='512.0', base_price=110000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Pro', 512)，跳过 i=100
# DEBUG: 处理行 i=101, model_raw='102', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=101 因为 model/cap 缺失
# DEBUG: 处理行 i=102, model_raw='103', model_norm='iPhone 14 Pro', cap='1024.0', base_price=120000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Pro', 1024)，跳过 i=102
# DEBUG: 处理行 i=103, model_raw='104', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=103 因为 model/cap 缺失
# DEBUG: 处理行 i=104, model_raw='105', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=104 因为 model/cap 缺失
# DEBUG: 处理行 i=105, model_raw='106', model_norm='iPhone 14 Pro Max', cap='128.0', base_price=110000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Pro Max', 128)，跳过 i=105
# DEBUG: 处理行 i=106, model_raw='107', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=106 因为 model/cap 缺失
# DEBUG: 处理行 i=107, model_raw='108', model_norm='iPhone 14 Pro Max', cap='256.0', base_price=120000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Pro Max', 256)，跳过 i=107
# DEBUG: 处理行 i=108, model_raw='109', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=108 因为 model/cap 缺失
# DEBUG: 处理行 i=109, model_raw='110', model_norm='iPhone 14 Pro Max', cap='512.0', base_price=130000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Pro Max', 512)，跳过 i=109
# DEBUG: 处理行 i=110, model_raw='111', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=110 因为 model/cap 缺失
# DEBUG: 处理行 i=111, model_raw='112', model_norm='iPhone 14 Pro Max', cap='1024.0', base_price=140000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Pro Max', 1024)，跳过 i=111
# DEBUG: 处理行 i=112, model_raw='113', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=112 因为 model/cap 缺失
# DEBUG: 处理行 i=113, model_raw='114', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=113 因为 model/cap 缺失
# DEBUG: 处理行 i=114, model_raw='115', model_norm='iPhone 14', cap='128.0', base_price=70000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14', 128)，跳过 i=114
# DEBUG: 处理行 i=115, model_raw='116', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=115 因为 model/cap 缺失
# DEBUG: 处理行 i=116, model_raw='117', model_norm='iPhone 14', cap='256.0', base_price=78000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14', 256)，跳过 i=116
# DEBUG: 处理行 i=117, model_raw='118', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=117 因为 model/cap 缺失
# DEBUG: 处理行 i=118, model_raw='119', model_norm='iPhone 14', cap='512.0', base_price=79000.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14', 512)，跳过 i=118
# DEBUG: 处理行 i=119, model_raw='120', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=119 因为 model/cap 缺失
# DEBUG: 处理行 i=120, model_raw='121', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=120 因为 model/cap 缺失
# DEBUG: 处理行 i=121, model_raw='122', model_norm='iPhone 14 Plus', cap='128.0', base_price=53500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Plus', 128)，跳过 i=121
# DEBUG: 处理行 i=122, model_raw='123', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=122 因为 model/cap 缺失
# DEBUG: 处理行 i=123, model_raw='124', model_norm='iPhone 14 Plus', cap='256.0', base_price=56500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Plus', 256)，跳过 i=123
# DEBUG: 处理行 i=124, model_raw='125', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=124 因为 model/cap 缺失
# DEBUG: 处理行 i=125, model_raw='126', model_norm='iPhone 14 Plus', cap='512.0', base_price=58500.0
# DEBUG: 对应的 color->pn 映射: None
# DEBUG: info 表中未找到该机型容量 key=('iPhone 14 Plus', 512)，跳过 i=125
# DEBUG: 处理行 i=126, model_raw='127', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=126 因为 model/cap 缺失
# DEBUG: 处理行 i=127, model_raw='128', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=127 因为 model/cap 缺失
# DEBUG: 处理行 i=128, model_raw='149', model_norm='', cap='64.0', base_price=45000.0
# DEBUG: 跳过 i=128 因为 model/cap 缺失
# DEBUG: 处理行 i=129, model_raw='150', model_norm='iPhone 13', cap='nan', base_price=nan
# DEBUG: 跳过 i=129 因为 model/cap 缺失
# DEBUG: 处理行 i=130, model_raw='151', model_norm='', cap='128.0', base_price=49000.0
# DEBUG: 跳过 i=130 因为 model/cap 缺失
# DEBUG: 处理行 i=131, model_raw='152', model_norm='', cap='nan', base_price=nan
# DEBUG: 跳过 i=131 因为 model/cap 缺失
# DEBUG: 完成 clean_shop7, 产出行数: 43
#    part_number shop_name  price_new          recorded_at
# 0     MG854J/A     買取ホムラ     176000  2025-10-27 15:57:47
# 1     MG864J/A     買取ホムラ     176000  2025-10-27 15:57:47
# 2     MG874J/A     買取ホムラ     176000  2025-10-27 15:57:47
# 3     MG894J/A     買取ホムラ     212000  2025-10-27 15:57:47
# 4     MG8A4J/A     買取ホムラ     212000  2025-10-27 15:57:47
# 5     MG8C4J/A     買取ホムラ     212000  2025-10-27 15:57:47
# 6     MG8D4J/A     買取ホムラ     245000  2025-10-27 15:57:47
# 7     MG8E4J/A     買取ホムラ     245000  2025-10-27 15:57:47
# 8     MG8F4J/A     買取ホムラ     245000  2025-10-27 15:57:47
# 9     MFY84J/A     買取ホムラ     198000  2025-10-27 15:57:47
# 10    MFY94J/A     買取ホムラ     198000  2025-10-27 15:57:47
# 11    MFYA4J/A     買取ホムラ     198000  2025-10-27 15:57:47
# 12    MFYC4J/A     買取ホムラ     229000  2025-10-27 15:57:47
# 13    MFYD4J/A     買取ホムラ     230500  2025-10-27 15:57:47
# 14    MFYE4J/A     買取ホムラ     229000  2025-10-27 15:57:47
# 15    MFYF4J/A     買取ホムラ     260000  2025-10-27 15:57:47
# 16    MFYG4J/A     買取ホムラ     263000  2025-10-27 15:57:47
# 17    MFYH4J/A     買取ホムラ     260000  2025-10-27 15:57:47
# 18    MFYJ4J/A     買取ホムラ     311000  2025-10-27 15:57:47
# 19    MFYK4J/A     買取ホムラ     314000  2025-10-27 15:57:47
# 20    MFYL4J/A     買取ホムラ     311000  2025-10-27 15:57:47
# 21    MG274J/A     買取ホムラ     127000  2025-10-27 15:57:47
# 22    MG284J/A     買取ホムラ     127000  2025-10-27 15:57:47
# 23    MG294J/A     買取ホムラ     127000  2025-10-27 15:57:47
# 24    MG2A4J/A     買取ホムラ     125000  2025-10-27 15:57:47
# 25    MG2C4J/A     買取ホムラ     136000  2025-10-27 15:57:47
# 26    MG2D4J/A     買取ホムラ     140000  2025-10-27 15:57:47
# 27    MG2E4J/A     買取ホムラ     140000  2025-10-27 15:57:47
# 28    MG2F4J/A     買取ホムラ     136000  2025-10-27 15:57:47
# 29    MG2G4J/A     買取ホムラ     150000  2025-10-27 15:57:47
# 30    MG2H4J/A     買取ホムラ     154000  2025-10-27 15:57:47
# 31    MG2J4J/A     買取ホムラ     154000  2025-10-27 15:57:47
# 32    MG2K4J/A     買取ホムラ     150000  2025-10-27 15:57:47
# 33    MG674J/A     買取ホムラ     128500  2025-10-27 15:57:47
# 34    MG684J/A     買取ホムラ     128500  2025-10-27 15:57:47
# 35    MG694J/A     買取ホムラ     128500  2025-10-27 15:57:47
# 36    MG6A4J/A     買取ホムラ     128500  2025-10-27 15:57:47
# 37    MG6C4J/A     買取ホムラ     128500  2025-10-27 15:57:47
# 38    MG6D4J/A     買取ホムラ     158000  2025-10-27 15:57:47
# 39    MG6E4J/A     買取ホムラ     158000  2025-10-27 15:57:47
# 40    MG6F4J/A     買取ホムラ     158000  2025-10-27 15:57:47
# 41    MG6G4J/A     買取ホムラ     158000  2025-10-27 15:57:47
# 42    MG6H4J/A     買取ホムラ     158000  2025-10-27 15:57:47
